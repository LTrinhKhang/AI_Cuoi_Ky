# %% [markdown]
# <a href="https://colab.research.google.com/github/LTrinhKhang/AI_Cuoi_Ky/blob/main/nhan_dien_xe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from numpy import asarray, save
from os import listdir
from keras.utils import img_to_array, load_img
from sklearn.model_selection import train_test_split
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D, LeakyReLU
from keras.optimizers import Adam
from keras.losses import categorical_crossentropy

# Đường dẫn đến thư mục chứa dữ liệu
folder = '/content/drive/MyDrive/Data1/'

# List để lưu trữ dữ liệu ảnh và nhãn
photos, labels = list(), list()

# Duyệt qua các tệp tin trong thư mục
for file in listdir(folder):
    output = 0  # Giá trị mặc định cho nhãn

    if file.startswith('D'):
        output = 1
    elif file.startswith('t'):
        output = 2
    elif file.startswith('O'):
        output = 3
    elif file.startswith('M'):
        output = 4

    # Đọc ảnh và chuyển đổi thành mảng numpy
    img = load_img(folder + file, target_size=(30, 40))
    photo = img_to_array(img)
    photos.append(photo)
    labels.append(output)

# Chuyển đổi danh sách thành mảng numpy
x = asarray(photos)
y = asarray(labels)

# Phân chia dữ liệu thành tập huấn luyện và tập kiểm tra
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.1, random_state=42)

# Chuẩn hóa dữ liệu ảnh và nhãn
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0
y_train = to_categorical(y_train, num_classes=5)
y_test = to_categorical(y_test, num_classes=5)

# Xây dựng mô hình CNN
model = Sequential()
# 32 lần tích chập 
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(30, 40, 3), padding='Same'))
model.add(MaxPooling2D((2, 2), padding='same'))
model.add(Dropout(0.25))

# 64 lần tích chập 
model.add(Conv2D(64, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D((2, 2), padding='same'))
model.add(Dropout(0.25))

# 128 lần tích chập 
model.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D((2, 2), padding='same'))
model.add(Dropout(0.25))

# 512 lần tích chập 
model.add(Conv2D(512, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D((2, 2), padding='same'))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(128, activation='linear'))
model.add(LeakyReLU(alpha=0.1))
model.add(Dense(5, activation='softmax'))
model.summary()

# Biên dịch mô hình
model.compile(loss='categorical_crossentropy', optimizer=Adam(), metrics=['accuracy'])

# Huấn luyện mô hình
model.fit(x_train, y_train, epochs=128, batch_size=10, verbose=1)

# Đánh giá mô hình trên tập kiểm tra
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_16 (Conv2D)          (None, 30, 40, 32)        896
#
#  max_pooling2d_16 (MaxPoolin  (None, 15, 20, 32)       0
#  g2D)
#
#  dropout_16 (Dropout)        (None, 15, 20, 32)        0
#
#  conv2d_17 (Conv2D)          (None, 15, 20, 64)        18496
#
#  max_pooling2d_17 (MaxPoolin  (None, 8, 10, 64)        0
#  g2D)
#
#  dropout_17 (Dropout)        (None, 8, 10, 64)         0
#
#  conv2d_18 (Conv2D)          (None, 8, 10, 128)        73856
#
#  max_pooling2d_18 (MaxPoolin  (None, 4, 5, 128)        0
#  g2D)
#
#  dropout_18 (Dropout)        (None, 4, 5, 128)         0
#
#  conv2d_19 (Conv2D)          (None, 4, 5, 512)         590336
#
#  max_pooling2d_19 (MaxPoolin  (None, 2, 3, 512)        0
#  g2D)
#
#  dropout_19 (Dropout)        (None, 2, 3, 512)         0
#
#  flatten_4 (Flatten)         (None, 3072)              0
#
#  dense_8 (Dense)             (None, 128)               393344
#
#  leaky_re_lu_4 (LeakyReLU)   (None, 128)               0
#
#  dense_9 (Dense)             (None, 5)                 645
#
# =================================================================
# Total params: 1,077,573
# Trainable params: 1,077,573
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/128
# 27/27 [==============================] - 1s 7ms/step - loss: 1.4709 - accuracy: 0.2406
# Epoch 2/128
# 27/27 [==============================] - 0s 5ms/step - loss: 1.4153 - accuracy: 0.2331
# Epoch 3/128
# 27/27 [==============================] - 0s 5ms/step - loss: 1.3632 - accuracy: 0.3308
# Epoch 4/128
# 27/27 [==============================] - 0s 5ms/step - loss: 1.2526 - accuracy: 0.4436
# Epoch 5/128
# 27/27 [==============================] - 0s 5ms/step - loss: 1.1075 - accuracy: 0.5188
# Epoch 6/128
# 27/27 [==============================] - 0s 5ms/step - loss: 0.9513 - accuracy: 0.5902
# Epoch 7/128
# 27/27 [==============================] - 0s 5ms/step - loss: 0.8560 - accuracy: 0.6692
# Epoch 8/128
# 27/27 [==============================] - 0s 5ms/step - loss: 0.7725 - accuracy: 0.6880
# Epoch 9/128
# 27/27 [==============================] - 0s 5ms/step - loss: 0.7617 - accuracy: 0.6917
# Epoch 10/128
# 27/27 [==============================] - 0s 5ms/step - loss: 0.6534 - accuracy: 0.7556
# Epoch 11/128
# 27/27 [==============================] - 0s 6ms/step - loss: 0.6513 - accuracy: 0.7519
# Epoch 12/128
# 27/27 [==============================] - 0s 5ms/step - loss: 0.6249 - accuracy: 0.7519
# Epoch 13/128
# 27/27 [==============================] - 0s 5ms/step - loss: 0.5232 - accuracy: 0.7932
# Epoch 14/128
# 27/27 [==============================] - 0s 5ms/step - loss: 0.4911 - accuracy: 0.8008
# Epoch 15/128
# 27/27 [==============================] - 0s 5ms/step - loss: 0.4601 - accuracy: 0.8083
# Epoch 16/128
# 27/27 [==============================] - 0s 5ms/step - loss: 0.3638 - accuracy: 0.8797
# Epoch 17/128
# 27/27 [==============================] - 0s 5ms/step - loss: 0.2508 - accuracy: 0.8947
# Epoch 18/128
# 27/27 [==============================] - 0s 5ms/step - loss: 0.2365 - accuracy: 0.9173
# Epoch 19/128
# 27/27 [==============================] - 0s 5ms/step - loss: 0.2358 - accuracy: 0.9060
# Epoch 20/128
# 27/27 [==============================] - 0s 5ms/step - loss: 0.1886 - accuracy: 0.9248
# Epoch 21/128
# 27/27 [==============================] - 0s 5ms/step - loss: 0.2290 - accuracy: 0.9286
# Epoch 22/128
# 27/27 [==============================] - 0s 5ms/step - loss: 0.1846 - accuracy: 0.9549
# Epoch 23/128
# 27/27 [==============================] - 0s 5ms/step - loss: 0.1035 - accuracy: 0.9624
# Epoch 24/128
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0948 - accuracy: 0.9662
# Epoch 25/128
# 27/27 [==============================] - 0s 7ms/step - loss: 0.1784 - accuracy: 0.9361
# Epoch 26/128
# 27/27 [==============================] - 0s 7ms/step - loss: 0.1124 - accuracy: 0.9662
# Epoch 27/128
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0580 - accuracy: 0.9887
# Epoch 28/128
# 27/27 [==============================] - 0s 7ms/step - loss: 0.1487 - accuracy: 0.9323
# Epoch 29/128
# 27/27 [==============================] - 0s 8ms/step - loss: 0.1330 - accuracy: 0.9586
# Epoch 30/128
# 27/27 [==============================] - 0s 9ms/step - loss: 0.2080 - accuracy: 0.9248
# Epoch 31/128
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0866 - accuracy: 0.9699
# Epoch 32/128
# 27/27 [==============================] - 0s 9ms/step - loss: 0.0561 - accuracy: 0.9850
# Epoch 33/128
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0477 - accuracy: 0.9812
# Epoch 34/128
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0897 - accuracy: 0.9737
# Epoch 35/128
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0448 - accuracy: 0.9850
# Epoch 36/128
# 27/27 [==============================] - 0s 7ms/step - loss: 0.1274 - accuracy: 0.9699
# Epoch 37/128
# 27/27 [==============================] - 0s 8ms/step - loss: 0.0928 - accuracy: 0.9737
# Epoch 38/128
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0702 - accuracy: 0.9662
# Epoch 39/128
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0774 - accuracy: 0.9737
# Epoch 40/128
# 27/27 [==============================] - 0s 10ms/step - loss: 0.0401 - accuracy: 0.9812
# Epoch 41/128
# 27/27 [==============================] - 0s 9ms/step - loss: 0.2137 - accuracy: 0.9436
# Epoch 42/128
# 27/27 [==============================] - 0s 8ms/step - loss: 0.0402 - accuracy: 0.9925
# Epoch 43/128
# 27/27 [==============================] - 0s 10ms/step - loss: 0.0152 - accuracy: 0.9962
# Epoch 44/128
# 27/27 [==============================] - 0s 9ms/step - loss: 0.0370 - accuracy: 0.9925
# Epoch 45/128
# 27/27 [==============================] - 0s 12ms/step - loss: 0.0340 - accuracy: 0.9812
# Epoch 46/128
# 27/27 [==============================] - 0s 14ms/step - loss: 0.0249 - accuracy: 0.9925
# Epoch 47/128
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0181 - accuracy: 0.9925
# Epoch 48/128
# 27/27 [==============================] - 0s 8ms/step - loss: 0.0331 - accuracy: 0.9850
# Epoch 49/128
# 27/27 [==============================] - 0s 9ms/step - loss: 0.0256 - accuracy: 0.9962
# Epoch 50/128
# 27/27 [==============================] - 0s 9ms/step - loss: 0.0243 - accuracy: 0.9925
# Epoch 51/128
# 27/27 [==============================] - 0s 9ms/step - loss: 0.0046 - accuracy: 1.0000
# Epoch 52/128
# 27/27 [==============================] - 0s 11ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 53/128
# 27/27 [==============================] - 0s 9ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 54/128
# 27/27 [==============================] - 0s 10ms/step - loss: 0.0164 - accuracy: 0.9925
# Epoch 55/128
# 27/27 [==============================] - 0s 10ms/step - loss: 0.0064 - accuracy: 1.0000
# Epoch 56/128
# 27/27 [==============================] - 0s 16ms/step - loss: 0.0072 - accuracy: 0.9962
# Epoch 57/128
# 27/27 [==============================] - 0s 12ms/step - loss: 0.0404 - accuracy: 0.9925
# Epoch 58/128
# 27/27 [==============================] - 0s 14ms/step - loss: 0.1412 - accuracy: 0.9699
# Epoch 59/128
# 27/27 [==============================] - 0s 11ms/step - loss: 0.0703 - accuracy: 0.9699
# Epoch 60/128
# 27/27 [==============================] - 0s 13ms/step - loss: 0.0529 - accuracy: 0.9887
# Epoch 61/128
# 27/27 [==============================] - 0s 14ms/step - loss: 0.1020 - accuracy: 0.9624
# Epoch 62/128
# 27/27 [==============================] - 0s 12ms/step - loss: 0.1837 - accuracy: 0.9323
# Epoch 63/128
# 27/27 [==============================] - 0s 10ms/step - loss: 0.0959 - accuracy: 0.9699
# Epoch 64/128
# 27/27 [==============================] - 0s 8ms/step - loss: 0.0923 - accuracy: 0.9737
# Epoch 65/128
# 27/27 [==============================] - 0s 10ms/step - loss: 0.0302 - accuracy: 0.9812
# Epoch 66/128
# 27/27 [==============================] - 0s 9ms/step - loss: 0.0100 - accuracy: 0.9962
# Epoch 67/128
# 27/27 [==============================] - 0s 9ms/step - loss: 0.0074 - accuracy: 0.9962
# Epoch 68/128
# 27/27 [==============================] - 0s 9ms/step - loss: 0.0084 - accuracy: 0.9962
# Epoch 69/128
# 27/27 [==============================] - 0s 12ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 70/128
# 27/27 [==============================] - 0s 11ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 71/128
# 27/27 [==============================] - 0s 11ms/step - loss: 0.0376 - accuracy: 0.9887
# Epoch 72/128
# 27/27 [==============================] - 0s 9ms/step - loss: 0.0847 - accuracy: 0.9774
# Epoch 73/128
# 27/27 [==============================] - 0s 9ms/step - loss: 0.0321 - accuracy: 0.9925
# Epoch 74/128
# 27/27 [==============================] - 0s 10ms/step - loss: 0.0123 - accuracy: 0.9962
# Epoch 75/128
# 27/27 [==============================] - 0s 8ms/step - loss: 0.0060 - accuracy: 0.9962
# Epoch 76/128
# 27/27 [==============================] - 0s 7ms/step - loss: 0.2626 - accuracy: 0.9211
# Epoch 77/128
# 27/27 [==============================] - 0s 11ms/step - loss: 0.2569 - accuracy: 0.9248
# Epoch 78/128
# 27/27 [==============================] - 0s 12ms/step - loss: 0.0829 - accuracy: 0.9737
# Epoch 79/128
# 27/27 [==============================] - 0s 9ms/step - loss: 0.0318 - accuracy: 0.9887
# Epoch 80/128
# 27/27 [==============================] - 0s 10ms/step - loss: 0.0243 - accuracy: 0.9925
# Epoch 81/128
# 27/27 [==============================] - 0s 9ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 82/128
# 27/27 [==============================] - 0s 10ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 83/128
# 27/27 [==============================] - 0s 9ms/step - loss: 0.0076 - accuracy: 0.9962
# Epoch 84/128
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 85/128
# 27/27 [==============================] - 0s 5ms/step - loss: 8.0859e-04 - accuracy: 1.0000
# Epoch 86/128
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 87/128
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 88/128
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 89/128
# 27/27 [==============================] - 0s 5ms/step - loss: 9.1644e-04 - accuracy: 1.0000
# Epoch 90/128
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0204 - accuracy: 0.9925
# Epoch 91/128
# 27/27 [==============================] - 0s 5ms/step - loss: 0.1139 - accuracy: 0.9887
# Epoch 92/128
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0255 - accuracy: 0.9850
# Epoch 93/128
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0078 - accuracy: 1.0000
# Epoch 94/128
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0377 - accuracy: 0.9887
# Epoch 95/128
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0490 - accuracy: 0.9925
# Epoch 96/128
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0073 - accuracy: 1.0000
# Epoch 97/128
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0419 - accuracy: 0.9850
# Epoch 98/128
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0238 - accuracy: 0.9887
# Epoch 99/128
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0193 - accuracy: 0.9887
# Epoch 100/128
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0163 - accuracy: 0.9925
# Epoch 101/128
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0230 - accuracy: 0.9887
# Epoch 102/128
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0779 - accuracy: 0.9850
# Epoch 103/128
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0391 - accuracy: 0.9850
# Epoch 104/128
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0058 - accuracy: 1.0000
# Epoch 105/128
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0081 - accuracy: 0.9962
# Epoch 106/128
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0187 - accuracy: 0.9925
# Epoch 107/128
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0427 - accuracy: 0.9887
# Epoch 108/128
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0815 - accuracy: 0.9850
# Epoch 109/128
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0233 - accuracy: 0.9962
# Epoch 110/128
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0437 - accuracy: 0.9850
# Epoch 111/128
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0083 - accuracy: 0.9962
# Epoch 112/128
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0444 - accuracy: 0.9925
# Epoch 113/128
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0428 - accuracy: 0.9887
# Epoch 114/128
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0454 - accuracy: 0.9887
# Epoch 115/128
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0144 - accuracy: 1.0000
# Epoch 116/128
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0066 - accuracy: 0.9962
# Epoch 117/128
# 27/27 [==============================] - 0s 6ms/step - loss: 6.1756e-04 - accuracy: 1.0000
# Epoch 118/128
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 119/128
# 27/27 [==============================] - 0s 6ms/step - loss: 0.1403 - accuracy: 0.9699
# Epoch 120/128
# 27/27 [==============================] - 0s 6ms/step - loss: 0.1258 - accuracy: 0.9662
# Epoch 121/128
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0642 - accuracy: 0.9774
# Epoch 122/128
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0143 - accuracy: 0.9925
# Epoch 123/128
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0102 - accuracy: 0.9962
# Epoch 124/128
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0203 - accuracy: 0.9925
# Epoch 125/128
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0273 - accuracy: 0.9925
# Epoch 126/128
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0110 - accuracy: 0.9962
# Epoch 127/128
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0124 - accuracy: 0.9925
# Epoch 128/128
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0010 - accuracy: 1.0000
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_test_function.<locals>.test_function at 0x7f00b02a3640> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Test loss: 0.29247480630874634
# Test accuracy: 0.8666666746139526

# %%
# Lưu mô hình
model.save('Nhan_dien_xe.h5')
